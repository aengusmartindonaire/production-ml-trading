# %% [markdown]
# # 1.2 Feature Set Analysis

# %% [markdown]
# Short description of this section.

# %%
from lrcm.features import RSK_COLS, EXTRA_FEATURES, build_extra_feature_decisions

# after you compute max_corr_with_core = {...}
extra_decisions_df = build_extra_feature_decisions(max_corr_with_core)
extra_decisions_df.head()
